# %%
# ==========================================
# MILESTONE 4 : SAVE MODELS
# ==========================================
import pickle
import os

# Create directory
if not os.path.exists('saved_models'):
    os.makedirs('saved_models')

print("Saving models to 'saved_models/' directory...")

# 1. Save DistilBERT (Category Model)
model_bert.save_pretrained("./saved_models/bert_category_model")
tokenizer.save_pretrained("./saved_models/bert_category_model")

# 2. Save Logistic Regression (Urgency Model) & Vectorizer
# We need the vectorizer to turn new text into numbers for the ML model
with open('./saved_models/urgency_model.pkl', 'wb') as f:
    pickle.dump(urgency_model, f)

with open('./saved_models/tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer_urgency, f)

print(" All models saved successfully!")
